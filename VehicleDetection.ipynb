# %% [markdown]
# <a href="https://colab.research.google.com/github/s0niaiqbal/Vehicle-Detection/blob/main/VehicleDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12273, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 12273 (delta 33), reused 35 (delta 15), pack-reused 12198
# Receiving objects: 100% (12273/12273), 12.64 MiB | 21.64 MiB/s, done.
# Resolving deltas: 100% (8436/8436), done.
# /content/yolov5
#      |████████████████████████████████| 1.6 MB 5.3 MB/s
#      |████████████████████████████████| 145 kB 5.2 MB/s
#      |████████████████████████████████| 178 kB 43.9 MB/s
#      |████████████████████████████████| 1.1 MB 25.9 MB/s
#      |████████████████████████████████| 67 kB 5.4 MB/s
#      |████████████████████████████████| 54 kB 2.3 MB/s
#      |████████████████████████████████| 138 kB 71.1 MB/s
#      |████████████████████████████████| 62 kB 1.3 MB/s
# ...
# Setup complete. Using torch 1.12.1+cu113 (CPU)

# %%
# !unzip /content/cars_Dataset.zip
# Out:
# Archive:  /content/cars_Dataset.zip
#    creating: cars_Dataset/images/
#    creating: cars_Dataset/images/training/
#   inflating: cars_Dataset/images/training/17873.jpg
#   inflating: cars_Dataset/images/training/3849.jpg
#   inflating: cars_Dataset/images/training/a11.jpg
#   inflating: cars_Dataset/images/training/a12.jpg
#   inflating: cars_Dataset/images/training/a13.jpg
#   inflating: cars_Dataset/images/training/a14.jpg
#   inflating: cars_Dataset/images/training/a15.jpg
#   inflating: cars_Dataset/images/training/a16.jpg
#   inflating: cars_Dataset/images/training/a17.jpg
#   inflating: cars_Dataset/images/training/a18.jpg
#   inflating: cars_Dataset/images/training/a19.jpg
#   inflating: cars_Dataset/images/training/a20.jpg
#   inflating: cars_Dataset/images/training/a21.jpg
#   inflating: cars_Dataset/images/training/a22.jpg
#   inflating: cars_Dataset/images/training/a23.jpg
#   inflating: cars_Dataset/images/training/a24.jpg
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/last.pt --img 640 --conf 0.25 --source https://www.youtube.com/watch?v=b-YNb2GmGhg
# Out:
# detect: weights=['runs/train/exp/weights/last.pt'], source=https://www.youtube.com/watch?v=b-YNb2GmGhg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-108-g23d0456 Python-3.7.13 torch-1.12.1+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# WARNING: Environment does not support cv2.imshow() or PIL Image.show() image displays
# cv2.imshow() is disabled in Docker environments
# requirements: YOLOv5 requirements "pafy" "youtube_dl==2020.12.2" not found, attempting AutoUpdate...
# ...

# %%
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')  # download (780M - 5000 images)
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip  # unzip
# Out:
#   0%|          | 0.00/780M [00:00<?, ?B/s]

# %%
# !python train.py --img 640 --batch 2 --epochs 40 --data /content/yolov5/data/custom_data.yml --weights yolov5s.pt --nosave --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/yolov5/data/custom_data.yml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=40, batch_size=2, imgsz=640, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-108-g23d0456 Python-3.7.13 torch-1.12.1+cu113 CPU
#
# ...
